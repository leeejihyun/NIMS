# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
import collections

# %%
#벡터 데이터 읽어오기
df = pd.read_csv('/Users/seulbeelee/dropbox/(A)Personal/nims/okt_total_vec_utf-8.csv')
df.head()
# Out:
#     0  가거라 삼팔선  가는 봄 오는 봄  가는 세월  가버린 당신  가을비 우산속  가을을  가장 무도회  가지 마오  갈대의 순정  \
# 0   너        4          0      0       0        0    0       0      0       0
# 1  사랑        0          0      0       2        0    4       1      6       1
# 2   내        0          0      4       0        0    2       0      1       0
# 3   나        0          0      0       0        2    0       0      0       0
# 4  그대        0          0      0       0        0    2       0      0       0
#
#    ...  그 흔한 남자여서  벌써 이렇게  이별(드라마"불새")  How Do I Say  4월의 눈물  남자는 속으로 운다  내가  \
# 0  ...          6       9            4            10       2           0   0
# 1  ...          2       7            7             4       2           4   6
# 2  ...          1       1            1            11       1           3   8
# 3  ...          0       5            2             2       0           0   0
# 4  ...          0       0            0             1       0           0   0
#
#    Sweety  Ring My Bell  기억을 흘리다
# ...

# %%
#column 이름 불러오기 (곡명)
col = df.columns
n = len(col)

# %%
titles = pd.DataFrame(data = col[1:])

# %%
ZZZZ = linkage(X[5386:],'single')
fig = plt.figure(figsize = (25,10))
dn = dendrogram(ZZZZ)
plt.show()
fig.savefig('/Users/seulbeelee/dropbox/(A)Personal/nims/OKT_dendro_single.png')

# %%
ZZZZ = linkage(X[5386:],'complete')
fig = plt.figure(figsize = (25,10))
dn = dendrogram(ZZZZ)
plt.show()
fig.savefig('./OKT_dendro_complete.png')

# %%
ZZZZ = linkage(X[5386:],'average')
fig = plt.figure(figsize = (25,10))
dn = dendrogram(ZZZZ)
plt.show()
fig.savefig('./OKT_dendro_average.png')

# %%
ZZZZ = linkage(X[5386:],'weighted')
fig = plt.figure(figsize = (25,10))
dn = dendrogram(ZZZZ)
plt.show()
fig.savefig('./OKT_dendro_weighted.png')

# %%
ZZZZ = linkage(X[5386:],'centroid')
fig = plt.figure(figsize = (25,10))
dn = dendrogram(ZZZZ)
plt.show()
fig.savefig('./OKT_dendro_centroid.png')

# %%
ZZZZ = linkage(X[5386:],'median')
fig = plt.figure(figsize = (25,10))
dn = dendrogram(ZZZZ)
plt.show()
fig.savefig('./OKT_dendro_median.png')

# %%
ZZZZ_tot = linkage(X,'ward')
fig = plt.figure(figsize = (30,7))
dn = dendrogram(ZZZZ_tot)
plt.show()
fig.savefig('./OKT_dendro_tot_ward.png')

# %%
df_temp = pd.read_csv('./gaza_lyric_utf-8.csv', engine = 'python')
del(df_temp['Unnamed: 0'])
del(df_temp['Unnamed: 0.1'])

# %%
c_g = collections.Counter(df_temp[df_temp['Color']=='g']['ARTIST'])
c_g.most_common(30)[1:]
# Out:
# [('유승준', 8),
#  ('조용필', 7),
#  ('김건모', 5),
#  ('김범수', 5),
#  ('조성모', 5),
#  ('H.O.T ', 5),
#  ('이수영', 5),
#  ('신승훈', 4),
#  ('박지윤', 4),
#  ('FLY TO THE SKY', 4),
#  ('현  철', 3),
#  ('박정운', 3),
#  ('공일오비', 3),
#  ('최유나', 3),
#  ('김광석', 3),
#  ('R.ef  ', 3),
#  ('터  보', 3),
#  ('태진아', 3),
#  ('이현우', 3),
#  ('쿨    ', 3),
#  ('THE S#ARP', 3),
#  ('소찬휘', 3),
#  ('고요태', 3),
#  ('드렁큰타이거', 3),
#  ('임희숙', 2),
#  ('변진섭', 2),
#  ('나훈아', 2),
#  ('최진희', 2),
#  ('김수희', 2)]

# %%
c_r = collections.Counter(df_temp[df_temp['Color']=='r']['ARTIST'])
c_r.most_common(30)[1:]
# Out:
# [('나훈아', 28),
#  ('이미자', 26),
#  ('조용필', 22),
#  ('쿨    ', 19),
#  ('패티김', 17),
#  ('이선희', 16),
#  ('변진섭', 15),
#  ('조성모', 15),
#  ('남인수', 14),
#  ('김건모', 14),
#  ('최진희', 13),
#  ('신승훈', 13),
#  ('이승환', 13),
#  ('이문세', 13),
#  ('김종서', 13),
#  ('남  진', 12),
#  ('심수봉', 11),
#  ('최희준', 11),
#  ('배  호', 11),
#  ('송대관', 11),
#  ('김원준', 11),
#  ('푸른하늘', 11),
#  ('THE S#ARP', 11),
#  ('김상희', 10),
#  ('문주란', 10),
#  ('강수지', 10),
#  ('송창식', 10),
#  ('양희은', 10),
#  ('서태지와아이들', 10)]

# %%
c_c = collections.Counter(df_temp[df_temp['Color']=='c']['ARTIST'])
c_c.most_common(20)[1:]
# Out:
# [('김완선', 1),
#  ('현  미', 1),
#  ('박일남', 1),
#  ('변진섭', 1),
#  ('조용필', 1),
#  ('남  진', 1),
#  ('C.Singelton & E.Snyder', 1),
#  ('윤종신', 1),
#  ('모자이크', 1),
#  ('장혜리', 1),
#  ('현  철', 1),
#  ('신성우', 1),
#  ('최재훈', 1),
#  ('김현식', 1),
#  ('봄여름가을겨울', 1),
#  ('뮤    ', 1),
#  ('강수지', 1),
#  ('패티김', 1),
#  ('김보희', 1)]

# %%
c_m = collections.Counter(df_temp[df_temp['Color']=='m']['ARTIST'])
c_m.most_common(20)[1:]
# Out:
# [('조용필', 22),
#  ('이승철', 20),
#  ('김건모', 17),
#  ('나훈아', 16),
#  ('이문세', 16),
#  ('임창정', 16),
#  ('쿨    ', 15),
#  ('윤종신', 13),
#  ('H.O.T ', 13),
#  ('김경호', 13),
#  ('THE S#ARP', 13),
#  ('김민종', 12),
#  ('신승훈', 12),
#  ('김원준', 12),
#  ('이미자', 11),
#  ('김종서', 11),
#  ('박상민', 11),
#  ('CLICK-B', 11),
#  ('이상우', 10)]
